# %% [markdown]
# #**DATE: 31-July-2024**

# %% [markdown]
# Lab1: Visualize the daily temperature changes over time in a city and give your
# conclusion.
#
# Input:
#
# days = list(range(1, 32))
#
# temperature = [65, 68, 70, 72, 75, 76, 78, 80, 81, 79, 75, 72, 70, 68, 67, 69, 70, 73, 75, 76, 78,80, 81, 82, 83, 82, 80, 78, 76, 74, 71]

# %%
import matplotlib.pyplot as plt

# Input data
days = list(range(1, 32))
temperature = [65, 68, 70, 72, 75, 76, 78, 80, 81, 79, 75, 72, 70, 68, 67, 69, 70, 73, 75, 76, 78, 80, 81, 82, 83, 82, 80, 78, 76, 74, 71]

# Plotting the data
plt.plot(days, temperature, marker='o',color='blue', label='Temperature')
plt.title('Daily Temperature Changes in July')
plt.xlabel('Day of the Month')
plt.ylabel('Temperature (°F)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Lab2: Create a line plot to visualize the daily closing prices of a stock over a year and give your conclusion.
#
# Input:
#
# days = list(range(1, 78))
#
# # Daily closing prices of a stock
#
# stock_prices = [100, 105, 110, 115, 112, 120,118, 125, 128, 130, 132, 135,138, 140, 142, 144, 145, 148,150, 155, 160, 158, 162, 165,170, 172, 175, 178, 180, 182,185, 188, 190, 192, 195, 198,200, 198, 195, 193, 190, 188,185, 182, 180, 178, 175, 172,170, 168, 165, 162, 160, 158,155, 152, 150, 148, 145, 143,140, 138, 135, 132, 130, 128,125, 123, 120, 118, 115, 112,110, 108, 105, 103, 100]

# %%
import matplotlib.pyplot as plt

# Input data
days = list(range(1, 78))
stock_prices = [100, 105, 110, 115, 112, 120, 118, 125, 128, 130, 132, 135, 138, 140, 142, 144, 145, 148, 150, 155, 160, 158, 162, 165, 170, 172, 175, 178, 180, 182, 185, 188, 190, 192, 195, 198, 200, 198, 195, 193, 190, 188, 185, 182, 180, 178, 175, 172, 170, 168, 165, 162, 160, 158, 155, 152, 150, 148, 145, 143, 140, 138, 135, 132, 130, 128, 125, 123, 120, 118, 115, 112, 110, 108, 105, 103, 100]

# Plotting the data
plt.figure(figsize=(12, 7))
plt.plot(days, stock_prices, marker='o', color='blue', label='Stock Price')
plt.title('Stock prices Over a Year')
plt.xlabel('Day of the Year')
plt.ylabel('Stock Price (USD)')
plt.legend()
plt.show()

# %% [markdown]
# #ChatGPT Exercise
#
# Using ChatGPT generate the python code to solve the same problem
# Hi! I have two column Date and sales with some dummy data. Can you please generate a line chart based on these two columns ?
#
# After generating the code using chatgpt, run the code, display the output and explain the conclusion.

# %%
import matplotlib.pyplot as plt
import datetime

# Dummy data
dates = [datetime.date(2023, 1, 1) + datetime.timedelta(days=i) for i in range(10)]
sales = [100, 150, 200, 250, 300, 350, 300, 250, 200, 150]

# Plotting the data
plt.figure(figsize=(10, 5))
plt.plot(dates, sales, marker='o', linestyle='-', color='b', label='Sales')
plt.title('Daily Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The line chart visualizes daily sales over a 10-day period. Here are the conclusions we can draw from the chart:
#
# * General Trend: Sales show a general increase from the start, peaking on the 6th day, and then gradually decreasing.
#
# * Peak Sales: The highest sales value is 350, which occurs on the 6th day.
#
# * Symmetry: The sales pattern is symmetric, with the first half showing an increasing trend and the second half showing a decreasing trend, returning to the initial sales value.
#
# This pattern suggests that there might be cyclical factors influencing sales, causing them to rise and fall in a predictable manner over this period.
